# %% [markdown]
# ### Import Framework

# %%
import ML_Framework_refactored as fw

# %% [markdown]
# ### Define the data and the model objects

# %%
data = fw.NBA_data()

# %%
model = fw.logistic_regression()

# %% [markdown]
# ### Train and validate the model on the data using corss-validation

# %%
conf_matrix,precision,accuracy,recall,f1_score = fw.skf_cross_val(X=data.X, y=data.y, model=model, number_of_splits=100)

# %%
eval_data = [precision,accuracy,recall,f1_score]

# %% [markdown]
# ### Visualize the results

# %%
fw.boxplot_eval_scores(eval_data,fig_height=10,fig_width=5)
